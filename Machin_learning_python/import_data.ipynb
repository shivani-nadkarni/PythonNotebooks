# %% [markdown]
# ## Read data from CSV file

# %%
import pandas as pd

# %%
csvdata = pd.read_csv("data/sales_data.csv")

# %%
csvdata.shape
# Out:
# (998, 13)

# %%
csvdata.columns
# Out:
# Index(['Transaction_date', 'Product', 'Price', 'Payment_Type', 'Name', 'City',
#        'State', 'Country', 'Account_Created', 'Last_Login', 'Latitude',
#        'Longitude', 'US Zip'],
#       dtype='object')

# %%
csvdata.dtypes
# Out:
# Transaction_date     object
# Product              object
# Price                 int64
# Payment_Type         object
# Name                 object
# City                 object
# State                object
# Country              object
# Account_Created      object
# Last_Login           object
# Latitude            float64
# Longitude           float64
# US Zip              float64
# dtype: object

# %%
csvdata.head(30)
# Out:
#     Transaction_date   Product  Price Payment_Type               Name  \
# 0   01/02/2009 04:53  Product1   1200         Visa             Betina
# 1   01/02/2009 13:08  Product1   1200   Mastercard  Federica e Andrea
# 2   01/04/2009 12:56  Product2   3600         Visa             Gerd W
# 3   01/04/2009 13:19  Product1   1200         Visa           LAURENCE
# 4   01/04/2009 20:11  Product1   1200   Mastercard              Fleur
# 5   01/02/2009 20:09  Product1   1200   Mastercard               adam
# 6   01/05/2009 02:42  Product1   1200       Diners              Stacy
# 7   01/02/2009 09:16  Product1   1200   Mastercard               Sean
# 8   01/05/2009 10:08  Product1   1200         Visa            Georgia
# 9   01/02/2009 14:18  Product1   1200         Visa            Richard
# 10  01/02/2009 07:35  Product1   1200       Diners               Hani
# 11  01/06/2009 07:18  Product1   1200         Visa             asuman
# ...

# %% [markdown]
# ## Skip rows while importing csv data

# %%
csvdata_skip = pd.read_csv("data/sales_data.csv", skiprows=[1,2,3,4])

# %%
csvdata_skip.shape
# Out:
# (994, 13)

# %% [markdown]
# ## Load the csv from web

# %%
csvweb_skipfoot = pd.read_csv("https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/04_Apply/Students_Alcohol_Consumption/student-mat.csv", skipfooter=150)
# Out:
# <ipython-input-13-9b63113829d2>:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   csvweb_skipfoot = pd.read_csv("https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/04_Apply/Students_Alcohol_Consumption/student-mat.csv", skipfooter=150)

# %%
csvweb_skipfoot.shape
# Out:
# (245, 33)

# %%
csvdata_nh = pd.read_csv("data/sales_data.csv", header=None)

# %%
csvdata_nh.head(20)
# Out:
#                   0         1      2             3                  4   \
# 0   Transaction_date   Product  Price  Payment_Type               Name
# 1   01/02/2009 04:53  Product1   1200          Visa             Betina
# 2   01/02/2009 13:08  Product1   1200    Mastercard  Federica e Andrea
# 3   01/04/2009 12:56  Product2   3600          Visa             Gerd W
# 4   01/04/2009 13:19  Product1   1200          Visa           LAURENCE
# 5   01/04/2009 20:11  Product1   1200    Mastercard              Fleur
# 6   01/02/2009 20:09  Product1   1200    Mastercard               adam
# 7   01/05/2009 02:42  Product1   1200        Diners              Stacy
# 8   01/02/2009 09:16  Product1   1200    Mastercard               Sean
# 9   01/05/2009 10:08  Product1   1200          Visa            Georgia
# 10  01/02/2009 14:18  Product1   1200          Visa            Richard
# 11  01/02/2009 07:35  Product1   1200        Diners               Hani
# ...

# %%
tsvdata = pd.read_csv("data/fly_data.tab", sep = '\t')

# %%
tsvdata.head()
# Out:
#             ID  EGF_Baseline  EGF_Stimulus
# 0  FBgn0029994         -1.25         -0.27
# 1  FBgn0037191         -1.05          0.78
# 2  FBgn0036810          2.08          1.34
# 3  FBgn0033320          1.15          0.45
# 4  FBgn0051156         -1.77         -0.76

# %% [markdown]
# ## Load from excel

# %%
exceldata = pd.read_excel("data/financial_data.xlsx", sheet_name = "Sheet1")

# %%
exceldata.head(19)
# Out:
#              Segment                   Country    Product Discount Band  \
# 0         Government                    Canada  Carretera          None
# 1         Government                   Germany  Carretera          None
# 2          Midmarket                    France  Carretera          None
# 3          Midmarket                   Germany  Carretera          None
# 4          Midmarket                    Mexico  Carretera          None
# 5         Government                   Germany  Carretera          None
# 6          Midmarket                   Germany    Montana          None
# 7   Channel Partners                    Canada    Montana          None
# 8         Government                    France    Montana          None
# 9   Channel Partners                   Germany    Montana          None
# 10         Midmarket                    Mexico    Montana          None
# 11        Enterprise                    Canada    Montana          None
# ...
